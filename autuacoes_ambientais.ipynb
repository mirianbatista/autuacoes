# %% [markdown]
# <a href="https://colab.research.google.com/github/mirianbatista/autuacoes/blob/master/autuacoes_ambientais.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dados_2019 = 'https://github.com/mirianbatista/autuacoes/blob/master/%5B1%5D-10147957_Planilha_AIs_de_08_10_19_a_31_12_19_SIC_5210_21.xlsx?raw=true'
dados_2020 = 'https://github.com/mirianbatista/autuacoes/blob/master/%5B2%5D-10147975_Planilha_AIs_2020_SIC_5210_21.xlsx?raw=true'
dados_2021 = 'https://github.com/mirianbatista/autuacoes/blob/master/%5B3%5D-10147989_Planilha_AIs_2021_SIC_5210_21.xlsx?raw=true'

# %%
dados2019 = pd.read_excel(dados_2019)
dados2020 = pd.read_excel(dados_2020)
dados2021 = pd.read_excel(dados_2021)

# %%
dados2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2121 entries, 0 to 2120
# Data columns (total 46 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   SEQ_AUTO_INFRACAO              1095 non-null   float64
#  1   REGISTRADO_SICAFI              2121 non-null   object
#  2   DES_STATUS_FORMULARIO          2121 non-null   object
#  3   SIT_CANCELADO                  1124 non-null   object
#  4   NUM_AUTO_INFRACAO              2121 non-null   object
#  5   SER_AUTO_INFRACAO              14 non-null     object
#  6   TIPO_AUTO                      1913 non-null   object
#  7   TIPO_MULTA                     2113 non-null   object
#  8   VAL_AUTO_INFRACAO              2098 non-null   float64
#  9   PATRIMONIO_APURACAO            4 non-null      object
#  10  GRAVIDADE_INFRACAO             495 non-null    object
#  11  UNID_ARRECADACAO               1095 non-null   object
#  12  DES_AUTO_INFRACAO              2105 non-null   object
#  13  DES_RECEITA                    2121 non-null   object
#  14  NO_TIPO_INFRACAO               2080 non-null   object
#  15  DAT_HORA_AUTO_INFRACAO         2121 non-null   datetime64[ns]
#  16  FORMA_ENTREGA                  2085 non-null   object
#  17  DAT_CIENCIA_AUTUACAO           1041 non-null   datetime64[ns]
#  18  DS_CONCILIACAO_UNIDADE         76 non-null     object
#  19  COD_MUNICIPIO                  2120 non-null   float64
#  20  NOM_MUNICIPIO                  2120 non-null   object
#  21  SIG_UF                         2120 non-null   object
#  22  BIOMA                          2116 non-null   object
#  23  UNIDADE_CONSERVACAO            1 non-null      object
#  24  NUM_PROCESSO                   957 non-null    float64
#  25  DES_INFRACAO                   2097 non-null   object
#  26  NOME_INFRATOR                  2115 non-null   object
#  27  CPF_CNPJ_INFRATOR              2107 non-null   object
#  28  QTD_AREA                       29 non-null     float64
#  29  INFRACAO_AREA                  1245 non-null   object
#  30  DES_OUTROS_TIPO_AREA           0 non-null      float64
#  31  NUM_LONGITUDE_AUTO             2103 non-null   float64
#  32  NUM_LATITUDE_AUTO              2108 non-null   float64
#  33  DES_LOCAL_INFRACAO             2118 non-null   object
#  34  SEQ_NOTIFICACAO                7 non-null      float64
#  35  UNID_CONTROLE                  1989 non-null   object
#  36  NOM_OPERACAO                   51 non-null     object
#  37  DES_TIPO_OPERACAO              1093 non-null   object
#  38  DS_ORGAO                       1957 non-null   object
#  39  OPERACAO_SOL_RECURSO           1867 non-null   object
#  40  DAT_LANCAMENTO                 1095 non-null   datetime64[ns]
#  41  DAT_ALTERACAO                  2119 non-null   datetime64[ns]
#  42  DES_TIPO_HISTORICO_FORMULARIO  1093 non-null   object
#  43  ENQUADRAMENTO                  2118 non-null   object
#  44  ENQUADRAMENTO_COMPLEMENTAR     609 non-null    object
#  45  DAT_ULTIMA_ATUALIZACAO         2121 non-null   datetime64[ns]
# dtypes: datetime64[ns](5), float64(9), object(32)
# memory usage: 762.4+ KB

# %%
dados2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9057 entries, 0 to 9056
# Data columns (total 46 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   SEQ_AUTO_INFRACAO              6651 non-null   float64
#  1   REGISTRADO_SICAFI              9057 non-null   object
#  2   DES_STATUS_FORMULARIO          9057 non-null   object
#  3   SIT_CANCELADO                  6892 non-null   object
#  4   NUM_AUTO_INFRACAO              9057 non-null   object
#  5   SER_AUTO_INFRACAO              3 non-null      object
#  6   TIPO_AUTO                      9055 non-null   object
#  7   TIPO_MULTA                     9033 non-null   object
#  8   VAL_AUTO_INFRACAO              8965 non-null   float64
#  9   PATRIMONIO_APURACAO            0 non-null      float64
#  10  GRAVIDADE_INFRACAO             1055 non-null   object
#  11  UNID_ARRECADACAO               6644 non-null   object
#  12  DES_AUTO_INFRACAO              8986 non-null   object
#  13  DES_RECEITA                    9057 non-null   object
#  14  NO_TIPO_INFRACAO               9031 non-null   object
#  15  DAT_HORA_AUTO_INFRACAO         9057 non-null   datetime64[ns]
#  16  FORMA_ENTREGA                  8966 non-null   object
#  17  DAT_CIENCIA_AUTUACAO           4289 non-null   datetime64[ns]
#  18  DS_CONCILIACAO_UNIDADE         8935 non-null   object
#  19  COD_MUNICIPIO                  9039 non-null   float64
#  20  NOM_MUNICIPIO                  9039 non-null   object
#  21  SIG_UF                         9039 non-null   object
#  22  BIOMA                          9053 non-null   object
#  23  UNIDADE_CONSERVACAO            80 non-null     object
#  24  NUM_PROCESSO                   6767 non-null   float64
#  25  DES_INFRACAO                   8980 non-null   object
#  26  NOME_INFRATOR                  9037 non-null   object
#  27  CPF_CNPJ_INFRATOR              9004 non-null   object
#  28  QTD_AREA                       63 non-null     float64
#  29  INFRACAO_AREA                  2819 non-null   object
#  30  DES_OUTROS_TIPO_AREA           0 non-null      float64
#  31  NUM_LONGITUDE_AUTO             9039 non-null   float64
#  32  NUM_LATITUDE_AUTO              9039 non-null   float64
#  33  DES_LOCAL_INFRACAO             9037 non-null   object
#  34  SEQ_NOTIFICACAO                17 non-null     float64
#  35  UNID_CONTROLE                  8974 non-null   object
#  36  NOM_OPERACAO                   69 non-null     object
#  37  DES_TIPO_OPERACAO              6648 non-null   object
#  38  DS_ORGAO                       8969 non-null   object
#  39  OPERACAO_SOL_RECURSO           8619 non-null   object
#  40  DAT_LANCAMENTO                 6651 non-null   datetime64[ns]
#  41  DAT_ALTERACAO                  9057 non-null   datetime64[ns]
#  42  DES_TIPO_HISTORICO_FORMULARIO  6651 non-null   object
#  43  ENQUADRAMENTO                  9039 non-null   object
#  44  ENQUADRAMENTO_COMPLEMENTAR     2076 non-null   object
#  45  DAT_ULTIMA_ATUALIZACAO         9057 non-null   datetime64[ns]
# dtypes: datetime64[ns](5), float64(10), object(31)
# memory usage: 3.2+ MB

# %%
dados2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 775 entries, 0 to 774
# Data columns (total 46 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   SEQ_AUTO_INFRACAO              464 non-null    float64
#  1   REGISTRADO_SICAFI              775 non-null    object
#  2   DES_STATUS_FORMULARIO          775 non-null    object
#  3   SIT_CANCELADO                  485 non-null    object
#  4   NUM_AUTO_INFRACAO              775 non-null    object
#  5   SER_AUTO_INFRACAO              0 non-null      float64
#  6   TIPO_AUTO                      775 non-null    object
#  7   TIPO_MULTA                     775 non-null    object
#  8   VAL_AUTO_INFRACAO              768 non-null    float64
#  9   PATRIMONIO_APURACAO            0 non-null      float64
#  10  GRAVIDADE_INFRACAO             151 non-null    object
#  11  UNID_ARRECADACAO               464 non-null    object
#  12  DES_AUTO_INFRACAO              770 non-null    object
#  13  DES_RECEITA                    775 non-null    object
#  14  NO_TIPO_INFRACAO               775 non-null    object
#  15  DAT_HORA_AUTO_INFRACAO         775 non-null    object
#  16  FORMA_ENTREGA                  768 non-null    object
#  17  DAT_CIENCIA_AUTUACAO           229 non-null    object
#  18  DS_CONCILIACAO_UNIDADE         773 non-null    object
#  19  COD_MUNICIPIO                  775 non-null    int64
#  20  NOM_MUNICIPIO                  775 non-null    object
#  21  SIG_UF                         775 non-null    object
#  22  BIOMA                          775 non-null    object
#  23  UNIDADE_CONSERVACAO            8 non-null      object
#  24  NUM_PROCESSO                   428 non-null    float64
#  25  DES_INFRACAO                   750 non-null    object
#  26  NOME_INFRATOR                  775 non-null    object
#  27  CPF_CNPJ_INFRATOR              772 non-null    object
#  28  QTD_AREA                       0 non-null      float64
#  29  INFRACAO_AREA                  317 non-null    object
#  30  DES_OUTROS_TIPO_AREA           0 non-null      float64
#  31  NUM_LONGITUDE_AUTO             775 non-null    float64
#  32  NUM_LATITUDE_AUTO              775 non-null    float64
#  33  DES_LOCAL_INFRACAO             775 non-null    object
#  34  SEQ_NOTIFICACAO                28 non-null     float64
#  35  UNID_CONTROLE                  775 non-null    object
#  36  NOM_OPERACAO                   5 non-null      object
#  37  DES_TIPO_OPERACAO              464 non-null    object
#  38  DS_ORGAO                       774 non-null    object
#  39  OPERACAO_SOL_RECURSO           657 non-null    object
#  40  DAT_LANCAMENTO                 464 non-null    object
#  41  DAT_ALTERACAO                  775 non-null    object
#  42  DES_TIPO_HISTORICO_FORMULARIO  464 non-null    object
#  43  ENQUADRAMENTO                  775 non-null    object
#  44  ENQUADRAMENTO_COMPLEMENTAR     222 non-null    object
#  45  DAT_ULTIMA_ATUALIZACAO         775 non-null    object
# dtypes: float64(10), int64(1), object(35)
# memory usage: 278.6+ KB

# %%
dfs = [dados2019, dados2020, dados2021]
autuacoes = pd.concat(dfs)

# %%
autuacoes
# Out:
#      SEQ_AUTO_INFRACAO  ... DAT_ULTIMA_ATUALIZACAO
# 0                  NaN  ...    2021-03-14 22:20:47
# 1            2036188.0  ...    2021-03-14 22:20:47
# 2            2039240.0  ...    2021-03-14 22:20:47
# 3            2041283.0  ...    2021-03-14 22:20:47
# 4                  NaN  ...    2021-03-14 22:20:47
# ..                 ...  ...                    ...
# 770                NaN  ...    2021-03-01 23:03:36
# 771                NaN  ...    2021-03-01 23:03:36
# 772          2042737.0  ...    2021-03-01 23:03:36
# 773          2043185.0  ...    2021-03-01 23:03:36
# 774                NaN  ...    2021-03-01 23:03:36
#
# [11953 rows x 46 columns]
